# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/Othercomputers/My Laptop/dataset_zip/"* "/content/code/dataset"
# !unzip -o dataset/webface_112x112.zip -d dataset/

# %%
# !mkdir -p /content/code/dataset
# %cd code
# Out:
# /content/code

# %%
import sys
sys.path.append("/content/code")

# %%
# !cp -rf "/content/code/src/face_verification/params/"* "/content/drive/Othercomputers/My Laptop/src/face_verification/params/"

# %%
# !python -m src.face_verification.train_face_embedder
# Out:
# Time : 0:00:12.412532 -- Training loss : 3.453800873678239 -- Validation loss : 1.1240082861947231 -- Saved
# Time : 0:00:12.879623 -- Training loss : 2.459455337680754 -- Validation loss : 0.9913151850465869 -- Saved
# Time : 0:00:12.660667 -- Training loss : 2.0621195543007773 -- Validation loss : 0.9497971857180361 -- Saved
# Time : 0:00:12.413309 -- Training loss : 1.766129409680601 -- Validation loss : 0.9173546560475083 -- Saved
# Time : 0:00:12.367626 -- Training loss : 1.5644903085270867 -- Validation loss : 0.8737445156105229 -- Saved
# Time : 0:00:11.340540 -- Training loss : 1.3725086704629366 -- Validation loss : 0.869307523868123 -- Saved

# %%
# !python -m src.face_verification.test_face_embedder
# Out:
# tensor(0.4960, device='cuda:0')
