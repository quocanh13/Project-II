# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp -r "/content/drive/Othercomputers/My Laptop/dataset_zip/webface_112x112.zip" "/content/code/dataset"
# !unzip -o dataset/webface_112x112.zip -d dataset/
# !cp -r "/content/drive/Othercomputers/My Laptop/dataset_zip/images.zip" "/content/code/dataset"
# !unzip -o dataset/images.zip -d dataset/
# !cp -r "/content/drive/Othercomputers/My Laptop/dataset_zip/WIDER_train.zip" "/content/code/dataset"
# !unzip -o dataset/WIDER_train.zip -d dataset/
# !cp -r "/content/drive/Othercomputers/My Laptop/dataset_zip/CelebA.zip" "/content/code/dataset"
# !unzip -o dataset/CelebA.zip -d dataset/

# %%
# !mkdir -p /content/code/dataset
# %cd code

# %%
import sys
sys.path.append("/content/code")

# %%
# !cp -r "/content/drive/Othercomputers/My Laptop/params" "/content/code/"

# %%
# !cp -rf "/content/code/params/"* "/content/drive/Othercomputers/My Laptop/params/"

# %%
# !cp -r "/content/drive/Othercomputers/My Laptop/src" "/content/code/"

# %%
# !python -m src.face_detection.train_faster_rcnn
# Out:
# Time: 0:06:02.849489 -- Loss: 1.2560168504714966
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/code/src/face_detection/train_faster_rcnn.py", line 54, in <module>
#     train(load_state=False, lr=0.001, epoch=5)
#   File "/content/code/src/face_detection/train_faster_rcnn.py", line 44, in train
#     loss_dict = faster_rcnn(images, targets)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/code/src/face_detection/faster_rcnn.py", line 51, in forward
#     return self.model(images, targets)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/models/detection/generalized_rcnn.py", line 117, in forward
#     proposals, proposal_losses = self.rpn(images, features, targets)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/models/detection/rpn.py", line 370, in forward
#     proposals = self.box_coder.decode(pred_bbox_deltas.detach(), anchors)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/models/detection/_utils.py", line 178, in decode
#     pred_boxes = self.decode_single(rel_codes, concat_boxes)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/models/detection/_utils.py", line 216, in decode_single
#     c_to_c_h = torch.tensor(0.5, dtype=pred_ctr_y.dtype, device=pred_h.device) * pred_h
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
