# %%
# %cd /kaggle/working/code

# %%
# !rclone copy "gdrive:src/face_detection" "/kaggle/working/code/src/face_detection"
# !python -m src.face_detection.train_faster_rcnn --model vgg16 --lr 0.001 --device cuda:1 --epoch 3 --size 10000 --param celeb_A

# %%
# !python -m src.face_verification.test_face_embedder  -m resnet50

# %%
# %cd /kaggle/working/code/
# !rclone copy "gdrive:src/face_detection" "/kaggle/working/code/src/face_detection"
# !python -m src.face_detection.faster_rcnn.train_faster_rcnn -m vgg16 -lr 0.001 -d cuda:1 -ep 3 -bs 64 -s 10000 -ds celeb_A
# Out:
# /kaggle/working/code
# False
# ./params/face_detection/vgg16/celeb_A.pth
# Epoch : 0 -- Time: 0:10:58.129356 -- Loss: 0.260286507833004
# Epoch : 1 -- Time: 0:11:18.924661 -- Loss: 0.14021567207574845
# Epoch : 2 -- Time: 0:11:18.031188 -- Loss: 0.11377354875802993
